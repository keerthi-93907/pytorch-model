# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthi-93907/pytorch-model/blob/main/simple_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
model=nn.Sequential(
    nn.Linear(2,4),
    nn.ReLU(),
    nn.Linear(4,1)
)

# %%
X=torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y=torch.tensor([[0.],[1.],[1.],[0.]])

# %% [markdown]
# # **Loss Function and Optimizer**
#
# *   MSELoss measures prediction error
# *   Adam optimizer updates weight efficiency

# %%
loss_fn=nn.MSELoss()
opt=torch.optim.Adam(model.parameters(),lr=0.01)

# %%
for _ in range(1000):
  opt.zero_grad()
  loss = loss_fn(model(X),y)
  loss.backward()
  opt.step()

# %% [markdown]
# # **Model Inference**

# %%
print(model(X))
# Out:
# tensor([[4.7081e-06],
#         [9.9997e-01],
#         [9.9997e-01],
#         [1.1319e-04]], grad_fn=<AddmmBackward0>)

# %%
# !pip install google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key='"GEMINI_API_KEY"')

# %%
from google.genai import types

response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Why is the sky blue?'
).text
print(response)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-333528624.py in <cell line: 0>()
#       1 from google.genai import types
#       2
# ----> 3 response = client.models.generate_content(
#       4     model='gemini-2.5-flash',
#       5     contents='Why is the sky blue?'
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5225     while remaining_remote_calls_afc > 0:
#    5226       i += 1
# -> 5227       response = self._generate_content(
#    5228           model=model, contents=contents, config=parsed_config
#    5229       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4007     request_dict = _common.encode_unserializable_types(request_dict)
#    4008
# -> 4009     response = self._api_client.request(
# ...
